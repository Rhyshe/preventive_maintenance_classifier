# %% [markdown]
# # **Predictive Maintenance using Random Forest Classifier**

# %% [markdown]
# **Project Overview**
#
# This project applies a supervised machine learning approach to predict machinery maintenance needs using sensor data. The goal is to identify whether a machine will require maintenance (binary classification) based on its operational features.
#
# We use a Random Forest Classifier and fine-tune it using GridSearchCV to achieve high performance.

# %%
#importing Libraries

import pandas as pd
import numpy as np
import seaborn as sns

# %%
#loading the data and reading it and making the target variable

df_raw = pd.read_csv('/content/Machine Downtime (1)copy.csv')
df = df_raw.copy()
df = df.drop(['Assembly_Line_No','Date'],axis = 1)
y = df.pop('Downtime')

display(y.value_counts())
# Out:
# Downtime
# Machine_Failure       1265
# No_Machine_Failure    1235
# Name: count, dtype: int64

# %% [markdown]
# # **Preproccesing**

# %%
df.head()
# Out:
#              Machine_ID  Hydraulic_Pressure(bar)  Coolant_Pressure(bar)  \
# 0  Makino-L1-Unit1-2013                    71.04               6.933725
# 1  Makino-L1-Unit1-2013                   125.33               4.936892
# 2  Makino-L3-Unit1-2015                    71.12               6.839413
# 3  Makino-L2-Unit1-2015                   139.34               4.574382
# 4  Makino-L1-Unit1-2013                    60.51               6.893182
#
#    Air_System_Pressure(bar)  Coolant_Temperature  \
# 0                  6.284965                 25.6
# 1                  6.196733                 35.3
# 2                  6.655448                 13.1
# 3                  6.560394                 24.4
# 4                  6.141238                  4.1
#
#    Hydraulic_Oil_Temperature(?C)  Spindle_Bearing_Temperature(?C)  \
# 0                           46.0                             33.4
# 1                           47.4                             34.6
# 2                           40.7                             33.0
# 3                           44.2                             40.6
# 4                           47.3                             31.4
#
#    Spindle_Vibration(?m)  Tool_Vibration(?m)  Spindle_Speed(RPM)  \
# 0                  1.291              26.492             25892.0
# 1                  1.382              25.274             19856.0
# 2                  1.319              30.608             19851.0
# 3                  0.618              30.791             18461.0
# 4                  0.983              25.516             26526.0
#
#    Voltage(volts)  Torque(Nm)  Cutting(kN)
# 0           335.0   24.055326         3.58
# 1           368.0   14.202890         2.68
# 2           325.0   24.049267         3.55
# 3           360.0   25.860029         3.55
# 4           354.0   25.515874         3.55

# %%
df.columns
df.shape
# Out:
# (2500, 13)

# %%
machine_means = df.groupby('Machine_ID').mean()
display(machine_means)
# Out:
#                       Hydraulic_Pressure(bar)  Coolant_Pressure(bar)  \
# Machine_ID
# Makino-L1-Unit1-2013               100.220548               4.959537
# Makino-L2-Unit1-2015               103.403586               4.931144
# Makino-L3-Unit1-2015               100.714398               4.949339
#
#                       Air_System_Pressure(bar)  Coolant_Temperature  \
# Machine_ID
# Makino-L1-Unit1-2013                  6.501796            18.811137
# Makino-L2-Unit1-2015                  6.509159            18.224658
# Makino-L3-Unit1-2015                  6.486905            18.621744
#
#                       Hydraulic_Oil_Temperature(?C)  \
# Machine_ID
# Makino-L1-Unit1-2013                      47.562025
# Makino-L2-Unit1-2015                      47.740722
# Makino-L3-Unit1-2015                      47.557512
#
#                       Spindle_Bearing_Temperature(?C)  Spindle_Vibration(?m)  \
# Machine_ID
# Makino-L1-Unit1-2013                        35.018234               0.995954
# Makino-L2-Unit1-2015                        34.973110               1.020964
# Makino-L3-Unit1-2015                        35.202211               1.012083
#
#                       Tool_Vibration(?m)  Spindle_Speed(RPM)  Voltage(volts)  \
# Machine_ID
# Makino-L1-Unit1-2013           25.313381        20358.289805      349.413517
# Makino-L2-Unit1-2015           25.411773        20284.630597      347.386335
# Makino-L3-Unit1-2015           25.516793        20175.889841      350.139706
#
#                       Torque(Nm)  Cutting(kN)
# Machine_ID
# Makino-L1-Unit1-2013   24.947256     2.774227
# Makino-L2-Unit1-2015   25.213688     2.793640
# Makino-L3-Unit1-2015   25.563235     2.780515

# %% [markdown]
# # **Imputation**

# %%
missing_values_by_machine = df.groupby('Machine_ID').apply(lambda x: x.isnull().sum())
display(missing_values_by_machine)
# Out:
# /tmp/ipython-input-34-433038156.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   missing_values_by_machine = df.groupby('Machine_ID').apply(lambda x: x.isnull().sum())
#                       Machine_ID  Hydraulic_Pressure(bar)  \
# Machine_ID
# Makino-L1-Unit1-2013           0                        4
# Makino-L2-Unit1-2015           0                        5
# Makino-L3-Unit1-2015           0                        1
#
#                       Coolant_Pressure(bar)  Air_System_Pressure(bar)  \
# Machine_ID
# Makino-L1-Unit1-2013                      5                         7
# Makino-L2-Unit1-2015                     10                         8
# Makino-L3-Unit1-2015                      4                         2
#
#                       Coolant_Temperature  Hydraulic_Oil_Temperature(?C)  \
# Machine_ID
# Makino-L1-Unit1-2013                    3                              5
# Makino-L2-Unit1-2015                    5                              5
# Makino-L3-Unit1-2015                    4                              6
#
#                       Spindle_Bearing_Temperature(?C)  Spindle_Vibration(?m)  \
# Machine_ID
# Makino-L1-Unit1-2013                                2                      6
# Makino-L2-Unit1-2015                                1                      2
# Makino-L3-Unit1-2015                                4                      3
#
#                       Tool_Vibration(?m)  Spindle_Speed(RPM)  Voltage(volts)  \
# Machine_ID
# Makino-L1-Unit1-2013                   6                   1               1
# Makino-L2-Unit1-2015                   5                   4               3
# Makino-L3-Unit1-2015                   0                   1               2
#
#                       Torque(Nm)  Cutting(kN)
# Machine_ID
# Makino-L1-Unit1-2013           8            1
# Makino-L2-Unit1-2015           6            3
# Makino-L3-Unit1-2015           7            3

# %%
for col in df.columns:
    if col != 'Machine_ID':
        for machine_id in df['Machine_ID'].unique():
            mean_value = machine_means.loc[machine_id, col]
            df.loc[df['Machine_ID'] == machine_id, col] = df.loc[df['Machine_ID'] == machine_id, col].fillna(mean_value)
display(df.isnull().sum())
# Out:
# Machine_ID                         0
# Hydraulic_Pressure(bar)            0
# Coolant_Pressure(bar)              0
# Air_System_Pressure(bar)           0
# Coolant_Temperature                0
# Hydraulic_Oil_Temperature(?C)      0
# Spindle_Bearing_Temperature(?C)    0
# Spindle_Vibration(?m)              0
# Tool_Vibration(?m)                 0
# Spindle_Speed(RPM)                 0
# Voltage(volts)                     0
# Torque(Nm)                         0
# Cutting(kN)                        0
# dtype: int64

# %%
df = df.drop('Machine_ID',axis = 1)

# %%
y = (y == "Machine_Failure").astype(int)
display(y.value_counts())
# Out:
# Downtime
# 1    1265
# 0    1235
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x = df
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=42)

# %% [markdown]
# # **Random Forest and Tuning**

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100, random_state=42)
scores = cross_val_score(model, x_train, y_train, cv=5, scoring='accuracy')
print("CV Accuracy: ", scores.mean())
# Out:
# CV Accuracy:  0.985

# %%
from sklearn.metrics import classification_report, roc_auc_score

model.fit(x_train, y_train)
y_pred = model.predict(x_test)

print(classification_report(y_test, y_pred))
print("AUC:", roc_auc_score(y_test, model.predict_proba(x_test)[:, 1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       247
#            1       0.98      1.00      0.99       253
#
#     accuracy                           0.99       500
#    macro avg       0.99      0.99      0.99       500
# weighted avg       0.99      0.99      0.99       500
#
# AUC: 0.9998639804131795

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(model, x_train, y_train, cv=5, scoring='accuracy')
print("CV Accuracy:", scores.mean(), "+/-", scores.std())
# Out:
# CV Accuracy: 0.985 +/- 0.004472135954999571

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

param_grid = {
    'n_estimators': [100,200],
    'max_depth': [10, 20],
    'min_samples_split': [2,5],
    'min_samples_leaf': [1, 2],
    'max_features': ['sqrt']
}

rf = RandomForestClassifier(random_state=42)

# Initialize GridSearchCV
grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1,  # Use all CPU cores
    verbose=2
)

# Fit the grid search to your data
grid_search.fit(x_train, y_train)

# Best parameters
print("Best Parameters: ", grid_search.best_params_)

# Best estimator accuracy
print("Best CV Score: ", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Best Parameters:  {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Best CV Score:  0.9875

# %%
best_model = grid_search.best_estimator_

# Evaluate on test set
test_accuracy = best_model.score(x_test, y_test)
print("Test Accuracy with best model: ", test_accuracy)
# Out:
# Test Accuracy with best model:  0.988

# %%
#checking for overfitting
train_acc = best_model.score(x_train, y_train)
print("Train Accuracy:", train_acc)
# Out:
# Train Accuracy: 0.9995

# %%
#Evaluation of model
from sklearn.metrics import confusion_matrix, classification_report

y_pred = best_model.predict(x_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[243   4]
#  [  2 251]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       247
#            1       0.98      0.99      0.99       253
#
#     accuracy                           0.99       500
#    macro avg       0.99      0.99      0.99       500
# weighted avg       0.99      0.99      0.99       500

# %%
import joblib
joblib.dump(best_model, "random_forest_maintenance_model.pkl")
# Out:
# ['random_forest_maintenance_model.pkl']

# %% [markdown]
#  Model used: Random Forest Classifier
# - Accuracy achieved: ~98.8% on test data
# - Balanced precision/recall scores
# - Hyperparameter tuning improved the baseline accuracy from ~98.5% to ~98.8%
